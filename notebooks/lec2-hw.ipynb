# %%
# Colab cell
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Adjust these two for YOUR repo
REPO_OWNER = "ywanglab"
REPO_NAME  = "STAT4160"   # e.g., unified-stocks-team1

BASE_DIR   = "/content/drive/MyDrive/dspt25"
CLONE_DIR  = f"{BASE_DIR}/{REPO_NAME}"
REPO_URL   = f"https://github.com/{REPO_OWNER}/{REPO_NAME}.git"

import os, pathlib
pathlib.Path(BASE_DIR).mkdir(parents=True, exist_ok=True)

# %%
import os, subprocess, shutil, pathlib

if not pathlib.Path(CLONE_DIR).exists():
    # !git clone {REPO_URL} {CLONE_DIR}
else:
    # If the folder exists, just ensure it's a git repo and pull latest
    os.chdir(CLONE_DIR)
    # !git status
    # !git pull --ff-only
os.chdir(CLONE_DIR)
print("Working dir:", os.getcwd())
# Out:
# Refresh index: 100% (84/84), done.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	notebooks/
#
# nothing added to commit but untracked files present (use "git add" to track)
# remote: Enumerating objects: 96, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 88 (delta 5), reused 87 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (88/88), 22.74 KiB | 40.00 KiB/s, done.
# From https://github.com/ywanglab/STAT4160
#    785c881..f06c03f  main       -> origin/main
# Updating 785c881..f06c03f
# Updating files: 100% (49/49), done.
# Fast-forward
#  .Rhistory                                          |   0
#  .../56FCF09C/bibliography-index/biblio-files       |   1 -
#  .../56FCF09C/bibliography-index/biblio-refblock    |   0
#  .Rproj.user/56FCF09C/pcs/files-pane.pper           |   9 -
#  .Rproj.user/56FCF09C/pcs/source-pane.pper          |   3 -
#  .Rproj.user/56FCF09C/pcs/windowlayoutstate.pper    |  14 -
#  .Rproj.user/56FCF09C/pcs/workbench-pane.pper       |   5 -
#  .Rproj.user/56FCF09C/rmd-outputs                   |   5 -
#  .Rproj.user/56FCF09C/saved_source_markers          |   1 -
#  .Rproj.user/56FCF09C/sources/per/t/0390154A        |  32 -
#  .../56FCF09C/sources/per/t/0390154A-contents       | 435 ------------
#  .Rproj.user/56FCF09C/sources/per/t/05BB412F        |  26 -
#  .../56FCF09C/sources/per/t/05BB412F-contents       |  49 --
#  .Rproj.user/56FCF09C/sources/per/t/38679E0A        |  29 -
#  .../56FCF09C/sources/per/t/38679E0A-contents       |   9 -
#  .Rproj.user/56FCF09C/sources/per/t/49745F0A        |  31 -
#  .../56FCF09C/sources/per/t/49745F0A-contents       | 751 ---------------------
#  .Rproj.user/56FCF09C/sources/per/t/75B7698E        |  31 -
#  .../56FCF09C/sources/per/t/75B7698E-contents       |  79 ---
#  .Rproj.user/56FCF09C/sources/per/t/78AB540F        |  32 -
#  .../56FCF09C/sources/per/t/78AB540F-contents       | 481 -------------
#  .Rproj.user/56FCF09C/sources/prop/0EF31CCD         |  11 -
#  .Rproj.user/56FCF09C/sources/prop/12777C20         |  11 -
#  .Rproj.user/56FCF09C/sources/prop/1C70D160         |  11 -
#  .Rproj.user/56FCF09C/sources/prop/3019967D         |  10 -
#  .Rproj.user/56FCF09C/sources/prop/320CFDF5         |  11 -
#  .Rproj.user/56FCF09C/sources/prop/480E6F55         |   6 -
#  .Rproj.user/56FCF09C/sources/prop/6FB59411         |  11 -
#  .Rproj.user/56FCF09C/sources/prop/7C0D2D06         |  11 -
#  .Rproj.user/56FCF09C/sources/prop/892D752D         |  11 -
#  .Rproj.user/56FCF09C/sources/prop/8AA0B52C         |  12 -
#  .Rproj.user/56FCF09C/sources/prop/90285CC2         |  12 -
#  .Rproj.user/56FCF09C/sources/prop/A157F1BB         |   9 -
#  .Rproj.user/56FCF09C/sources/prop/D3E5B91C         |  11 -
#  .Rproj.user/56FCF09C/sources/prop/D434B448         |  12 -
#  .Rproj.user/56FCF09C/sources/prop/D4FA7A0D         |  11 -
#  .Rproj.user/56FCF09C/sources/prop/DB6F4BBA         |  11 -
#  .Rproj.user/56FCF09C/sources/prop/E1EA4C34         |  11 -
#  .Rproj.user/56FCF09C/sources/prop/E88EAB21         |  12 -
#  .Rproj.user/56FCF09C/sources/prop/ECA8A49C         |  11 -
#  .Rproj.user/56FCF09C/sources/prop/INDEX            |  19 -
#  .Rproj.user/shared/notebooks/patch-chunk-names     |   0
#  .Rproj.user/shared/notebooks/paths                 |  18 -
#  .gitignore                                         |   5 +
#  notebooks/lec2_inclass.ipynb                       |   1 +
#  notebooks/reproducibility_demo.ipynb               |   1 +
#  notebooks/system_check.ipynb                       |   1 +
#  reports/environment.json                           |  10 +
#  reports/seed_fingerprint.json                      |  39 ++
#  49 files changed, 57 insertions(+), 2265 deletions(-)
#  delete mode 100644 .Rhistory
#  delete mode 100644 .Rproj.user/56FCF09C/bibliography-index/biblio-files
#  delete mode 100644 .Rproj.user/56FCF09C/bibliography-index/biblio-refblock
#  delete mode 100644 .Rproj.user/56FCF09C/pcs/files-pane.pper
#  delete mode 100644 .Rproj.user/56FCF09C/pcs/source-pane.pper
#  delete mode 100644 .Rproj.user/56FCF09C/pcs/windowlayoutstate.pper
#  delete mode 100644 .Rproj.user/56FCF09C/pcs/workbench-pane.pper
#  delete mode 100644 .Rproj.user/56FCF09C/rmd-outputs
#  delete mode 100644 .Rproj.user/56FCF09C/saved_source_markers
#  delete mode 100644 .Rproj.user/56FCF09C/sources/per/t/0390154A
#  delete mode 100644 .Rproj.user/56FCF09C/sources/per/t/0390154A-contents
#  delete mode 100644 .Rproj.user/56FCF09C/sources/per/t/05BB412F
#  delete mode 100644 .Rproj.user/56FCF09C/sources/per/t/05BB412F-contents
#  delete mode 100644 .Rproj.user/56FCF09C/sources/per/t/38679E0A
#  delete mode 100644 .Rproj.user/56FCF09C/sources/per/t/38679E0A-contents
#  delete mode 100644 .Rproj.user/56FCF09C/sources/per/t/49745F0A
#  delete mode 100644 .Rproj.user/56FCF09C/sources/per/t/49745F0A-contents
#  delete mode 100644 .Rproj.user/56FCF09C/sources/per/t/75B7698E
#  delete mode 100644 .Rproj.user/56FCF09C/sources/per/t/75B7698E-contents
#  delete mode 100644 .Rproj.user/56FCF09C/sources/per/t/78AB540F
#  delete mode 100644 .Rproj.user/56FCF09C/sources/per/t/78AB540F-contents
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/0EF31CCD
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/12777C20
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/1C70D160
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/3019967D
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/320CFDF5
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/480E6F55
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/6FB59411
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/7C0D2D06
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/892D752D
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/8AA0B52C
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/90285CC2
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/A157F1BB
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/D3E5B91C
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/D434B448
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/D4FA7A0D
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/DB6F4BBA
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/E1EA4C34
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/E88EAB21
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/ECA8A49C
#  delete mode 100644 .Rproj.user/56FCF09C/sources/prop/INDEX
#  delete mode 100644 .Rproj.user/shared/notebooks/patch-chunk-names
#  delete mode 100644 .Rproj.user/shared/notebooks/paths
#  create mode 100644 notebooks/lec2_inclass.ipynb
#  create mode 100644 notebooks/reproducibility_demo.ipynb
#  create mode 100644 notebooks/system_check.ipynb
#  create mode 100644 reports/environment.json
#  create mode 100644 reports/seed_fingerprint.json
# fatal: cannot exec '.git/hooks/post-merge': Permission denied
# Working dir: /content/drive/MyDrive/dspt25/STAT4160

# %%
# Run in your repo root
import os, pathlib, textwrap
pathlib.Path(".github").mkdir(exist_ok=True)
tpl = textwrap.dedent("""\
    ## Summary
    What does this PR do and why?

    ## Changes
    -

    ## How to test
    - From a fresh clone: steps to run

    ## Checklist
    - [ ] Runs from a fresh clone (README steps)
    - [ ] No secrets committed; `.env` only (and `.env.example` updated if needed)
    - [ ] Large artifacts tracked by LFS (`git lfs ls-files` shows expected files)
    - [ ] Clear, small diff; comments where useful
""")
open(".github/pull_request_template.md","w").write(tpl)
print("Wrote .github/pull_request_template.md")
# Out:
# Wrote .github/pull_request_template.md

# %%
owners = """\
# Replace with your GitHub handles
* @teammate1 @teammate2 @ywanglab
"""
open(".github/CODEOWNERS","w").write(owners)
print("Wrote .github/CODEOWNERS (edit handles!)")
# Out:
# Wrote .github/CODEOWNERS (edit handles!)

# %%
# tools/guard_large_files.py
import os, subprocess, sys

LIMIT_MB = 10
ROOT = os.getcwd()

def lfs_tracked_paths(): # find files tracked by lfs
    try:
        out = subprocess.check_output(["git", "lfs", "ls-files"], text=True)
        tracked = set()
        for line in out.strip().splitlines():
            # line format: "<oid> <path>" ex: line = "3b2d8c7d53   data/processed/file.parquet"
            p = line.split(None, 1)[-1].strip() #split on whitespace at most once.
            tracked.add(os.path.normpath(p)) # normpath(p): ensure consistent slashes (\ vs /)
        return tracked
    except Exception:
        return set()

def humanize(bytes_):
    return f"{bytes_/(1024*1024):.2f} MB"

lfs_set = lfs_tracked_paths()
bad = []
for dirpath, dirnames, filenames in os.walk(ROOT):
  #os.walk() is a generator that recursively traverses a directory tree.
  # At each step it yields a tuple:(dirpath, subdirnames, filenames)

    # skip .git directory
    if ".git" in dirpath.split(os.sep):#using os specific separator os.sep (/ for linus, \ for windows)
        continue
    for fn in filenames:
        path = os.path.normpath(os.path.join(dirpath, fn))
        try:
            size = os.path.getsize(path)
        except FileNotFoundError:
            continue
        if size >= LIMIT_MB * 1024 * 1024:
            rel = os.path.relpath(path, ROOT)
            if rel not in lfs_set:
                bad.append((rel, size))

if bad:
    print("ERROR: Large non-LFS files found:")
    for rel, size in bad:
        print(f" - {rel} ({humanize(size)})")
    sys.exit(1)
else:
    print("OK: No large non-LFS files detected.")
# Out:
# OK: No large non-LFS files detected.

# %%
# Define the path to the tools directory
tools_dir = Path("tools")

# Create it if it doesn't exist (including any parents)
tools_dir.mkdir(parents=True, exist_ok=True)

print(f"Directory '{tools_dir}' is ready.")
# Out:
# Directory 'tools' is ready.

# %%
from pathlib import Path

tools_dir = Path("tools")
tools_dir.mkdir(parents=True, exist_ok=True)

script = tools_dir / "guard_large_files.py"

code = '''#!/usr/bin/env python3
import os
import sys
import subprocess

LIMIT_MB = 10  # size threshold for LFS in megabytes
ROOT = os.path.abspath(os.path.dirname(__file__) + "/..")

def humanize(nbytes):
    # format size in human-friendly units
    for unit in ['B','KB','MB','GB','TB']:
        if nbytes < 1024:
            return f"{nbytes:.1f}{unit}"
        nbytes /= 1024
    return f"{nbytes:.1f}PB"

def lfs_tracked_paths():
    try:
        out = subprocess.check_output(["git", "lfs", "ls-files"], text=True)
        tracked = set()
        for line in out.strip().splitlines():
            # line format: "<oid> <path>"
            p = line.split(None, 1)[-1].strip()
            tracked.add(os.path.normpath(p))
        return tracked
    except Exception:
        return set()

def main():
    lfs_set = lfs_tracked_paths()
    bad = []
    for dirpath, dirnames, filenames in os.walk(ROOT):
        # skip .git and other hidden dirs
        if ".git" in dirpath.split(os.sep):
            continue
        for fn in filenames:
            path = os.path.normpath(os.path.join(dirpath, fn))
            try:
                size = os.path.getsize(path)
            except FileNotFoundError:
                continue
            if size >= LIMIT_MB * 1024 * 1024:
                rel = os.path.relpath(path, ROOT)
                if rel not in lfs_set:
                    bad.append((rel, size))

    if bad:
        print("ERROR: Large non-LFS files found:")
        for rel, size in sorted(bad, key=lambda x: x[1], reverse=True):
            print(f" - {rel} ({humanize(size)})")
        sys.exit(1)
    else:
        print(f"OK: No large non-LFS files detected (limit {LIMIT_MB} MB).")

if __name__ == "__main__":
    main()
'''

# Write the file
script.write_text(code)
script.chmod(0o755)  # make it executable 0o means base-8. r:4, w: 2, x:1

print(f"Created {script}")
# Out:
# Created tools/guard_large_files.py

# %%
# Create/append Makefile target
from pathlib import Path
text = "\n\nguard:\n\tpython tools/guard_large_files.py\n" # guard: Makefile target. \t: tab required.
p = Path("Makefile") # point to the Makefile
# p.write_text(p.read_text() + text if p.exists() else text) # if p exists, read exising content and append text and overwrites.
# the above code will append text everytime, casue error if repeatedly excute.
if p.exists():
    content = p.read_text()
    if "guard:" not in content:
        p.write_text(content + text)
else:
    p.write_text(text)

print("Added 'guard' target to Makefile")
# Out:
# Added 'guard' target to Makefile

# %%
# !python tools/guard_large_files.py
# Out:
# OK: No large non-LFS files detected (limit 10 MB).
